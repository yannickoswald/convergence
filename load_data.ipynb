# %%
'''This script imports all the required country data from the WID (World Inequality Database)'''
## Load country names, codes and regions
import os
import pandas as pd

file_path = os.path.join('.', 'data/wid_all_data', 'WID_countries_modified.csv')

if os.path.exists(file_path):
    with open(file_path, encoding='unicode_escape') as f:
        countries = pd.read_csv(f, sep = ";")
else:
    print("File not found. Please check the file path.")

# Remove two commas from the end of each string in the specified column
countries.rename(columns={'region2,,' : 'region2'}, inplace=True)
countries['region2'] = countries['region2'].str.rstrip(',')

# Print the header of the DataFrame
print(countries.head())
# Out:
#   alpha2                 titlename             shortname    region  \
# 0     AD                   Andorra               Andorra    Europe
# 1     AE  the United Arab Emirates  United Arab Emirates      Asia
# 2     AF               Afghanistan           Afghanistan      Asia
# 3     AG       Antigua and Barbuda   Antigua and Barbuda  Americas
# 4     AI                  Anguilla              Anguilla  Americas
#
#           region2
# 0  Western Europe
# 1       West Asia
# 2      South Asia
# 3       Caribbean
# 4       Caribbean

# %%
#aptincj992 is pre tax national income per adult (not per adult equivalent I think)
# Define your desired directory
desired_directory = r'C:\Users\y-osw\Dropbox\Arbeit\postdoc_lausanne\convergence\data\wid_all_data'

# Base path for debugging
file_path_to_data = os.path.join('.', 'data\wid_all_data')
print("Base path:", file_path_to_data)
print("Current working directory:", os.getcwd())

# Assuming 'data' is your main DataFrame
# Initialize a dictionary to store the subset dataframes
subset_dfs = {}

# Iterate over the unique codes in the 'alpha2' column
for code in countries['alpha2'].unique():
    # Construct the file name for the respective dataframe
    file_name = f'WID_data_{code}.csv'  # Assuming the files are .csv
    full_file_path = os.path.join(desired_directory, file_name)

    # Check if the file exists
    if os.path.exists(full_file_path):
        # Load the dataframe
        df = pd.read_csv(full_file_path, sep = ";")        
        # Print column names for debugging
        print("Columns in DataFrame:", df.columns)

        # Subset the dataframe based on two variables: 'aptincj992' and 'ntaxad999i'
        # for pre-tax national income distributional accounts and 'year'
        subset_df = df[(df['variable'] == 'aptincj992') & (df['year'] == 2021)]

        # Store the subset dataframe in the dictionary
        subset_dfs[code] = subset_df

        print(subset_df)
        
        # Delete the full dataframe to clear memory
        del df
    else:
        print(f"File not found: {full_file_path}")


# Check if all dataframes have the same format/dimensions
if subset_dfs:  # Check if there's at least one dataframe in the dictionary
    first_df_shape = next(iter(subset_dfs.values())).shape
    consistent_format = all(df.shape == first_df_shape for df in subset_dfs.values())

    if consistent_format:
        print("All dataframes have the same format and dimensions.")
    else:
        print("Dataframes differ in format/dimensions.")
else:
    print("No dataframes were loaded.")
# Out:
# Base path: .\data\wid_all_data
# Current working directory: c:\Users\y-osw\Dropbox\Arbeit\postdoc_lausanne\convergence
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable percentile  year     value  age pop
# 25401      AE  aptincj992      p0p10  2021    4318.1  992   j
# 25443      AE  aptincj992     p0p100  2021  222942.6  992   j
# 25485      AE  aptincj992      p0p50  2021   57102.6  992   j
# 25527      AE  aptincj992      p0p99  2021  190712.1  992   j
# 25569      AE  aptincj992    p10p100  2021  247234.2  992   j
# ...       ...         ...        ...   ...       ...  ...  ..
# 40435      AE  aptincj992     p67p68  2021  186053.8  992   j
# 40477      AE  aptincj992     p6p100  2021  237154.6  992   j
# 40519      AE  aptincj992    p71p100  2021  552704.7  992   j
# 40561      AE  aptincj992     p73p74  2021  216198.5  992   j
# 40603      AE  aptincj992    p81p100  2021  723392.5  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable      percentile  year      value  age pop
# 1593       AF  aptincj992           p0p11  2021      287.6  992   j
# 1635       AF  aptincj992           p0p12  2021      418.9  992   j
# 1677       AF  aptincj992           p0p13  2021      576.6  992   j
# 1719       AF  aptincj992           p0p14  2021      761.8  992   j
# 1761       AF  aptincj992           p0p15  2021      975.3  992   j
# ...       ...         ...             ...   ...        ...  ...  ..
# 45597      AF  aptincj992          p56p57  2021    52141.4  992   j
# 45639      AF  aptincj992         p66p100  2021   142606.1  992   j
# 45681      AF  aptincj992          p83p84  2021    90307.9  992   j
# 45723      AF  aptincj992      p99.1p99.2  2021   531153.5  992   j
# 45765      AF  aptincj992  p99.992p99.993  2021  7057505.4  992   j
#
# [387 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable percentile  year      value  age pop
# 1853       AM  aptincj992      p0p11  2021     9284.2  992   j
# 1895       AM  aptincj992      p0p12  2021    13519.3  992   j
# 1937       AM  aptincj992      p0p13  2021    18610.5  992   j
# 1979       AM  aptincj992      p0p14  2021    24587.1  992   j
# 2021       AM  aptincj992      p0p15  2021    31479.8  992   j
# ...       ...         ...        ...   ...        ...  ...  ..
# 55409      AM  aptincj992     p70p71  2021  2912935.6  992   j
# 55451      AM  aptincj992    p73p100  2021  8116907.6  992   j
# 55493      AM  aptincj992    p76p100  2021  8722128.0  992   j
# 55535      AM  aptincj992    p79p100  2021  9453576.6  992   j
# 55577      AM  aptincj992     p80p90  2021  4753798.6  992   j
#
# [387 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable  percentile  year       value  age pop
# 25479      AO  aptincj992        p0p1  2021         0.0  992   j
# 25521      AO  aptincj992       p0p10  2021     38639.5  992   j
# 25563      AO  aptincj992      p0p100  2021   3023758.5  992   j
# 25605      AO  aptincj992       p0p50  2021    546564.9  992   j
# 25647      AO  aptincj992       p0p90  2021   1410761.5  992   j
# ...       ...         ...         ...   ...         ...  ...  ..
# 36441      AO  aptincj992    p99p99.1  2021  29569308.2  992   j
# 36483      AO  aptincj992       p9p10  2021    139101.6  992   j
# 36525      AO  aptincj992      p9p100  2021   3320094.0  992   j
# 41182      AO  aptincj992  p99.6p99.7  2021  55962061.7  992   j
# 46348      AO  aptincj992     p54p100  2021   5867224.4  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#        country    variable percentile  year      value  age pop
# 15654       AR  aptincj992       p0p1  2021        0.0  992   j
# 15696       AR  aptincj992      p0p10  2021        0.0  992   j
# 15738       AR  aptincj992     p0p100  2021  2108862.3  992   j
# 15780       AR  aptincj992      p0p50  2021   554831.9  992   j
# 15822       AR  aptincj992      p0p90  2021  1235454.9  992   j
# ...        ...         ...        ...   ...        ...  ...  ..
# 94816       AR  aptincj992    p58p100  2021  4110076.9  992   j
# 94858       AR  aptincj992     p78p79  2021  2360683.6  992   j
# 132940      AR  aptincj992       p4p5  2021        0.0  992   j
# 132982      AR  aptincj992     p5p100  2021  2219855.0  992   j
# 142709      AR  aptincj992      p9p10  2021        0.0  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable percentile  year      value  age pop
# 54309      AT  aptincj992       p0p1  2021        0.0  992   j
# 54351      AT  aptincj992      p0p10  2021     1858.1  992   j
# 54393      AT  aptincj992     p0p100  2021    47801.0  992   j
# 54435      AT  aptincj992      p0p50  2021    21188.9  992   j
# 54477      AT  aptincj992      p0p90  2021    34816.4  992   j
# ...       ...         ...        ...   ...        ...  ...  ..
# 65271      AT  aptincj992     p9p100  2021    52397.9  992   j
# 89244      AT  aptincj992    p71p100  2021    97443.7  992   j
# 89286      AT  aptincj992     p86p87  2021    71166.5  992   j
# 89328      AT  aptincj992  p99.8p100  2021  1213866.9  992   j
# 89370      AT  aptincj992      p9p10  2021     6689.0  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#        country    variable   percentile  year      value  age pop
# 81087       AU  aptincj992         p0p1  2021        0.0  992   j
# 81159       AU  aptincj992        p0p10  2021     2149.1  992   j
# 81231       AU  aptincj992       p0p100  2021    93694.5  992   j
# 81303       AU  aptincj992        p0p11  2021      238.8  992   j
# 81375       AU  aptincj992        p0p12  2021      347.7  992   j
# ...        ...         ...          ...   ...        ...  ...  ..
# 108591      AU  aptincj992  p99.9p99.91  2021  1334814.7  992   j
# 108663      AU  aptincj992      p99p100  2021   929407.4  992   j
# 108735      AU  aptincj992     p99p99.1  2021   543077.0  992   j
# 108807      AU  aptincj992        p9p10  2021     7736.9  992   j
# 108879      AU  aptincj992       p9p100  2021   102809.8  992   j
#
# [387 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year     value  age pop
# 1878       AZ  aptincj992        p0p11  2021      44.2  992   j
# 1920       AZ  aptincj992        p0p12  2021      64.3  992   j
# 1962       AZ  aptincj992        p0p13  2021      88.5  992   j
# 2004       AZ  aptincj992        p0p14  2021     117.0  992   j
# 2046       AZ  aptincj992        p0p15  2021     149.8  992   j
# ...       ...         ...          ...   ...       ...  ...  ..
# 48292      AZ  aptincj992  p99.9p99.91  2021  410671.2  992   j
# 48334      AZ  aptincj992      p99p100  2021  237477.6  992   j
# 48376      AZ  aptincj992     p99p99.1  2021  104930.7  992   j
# 48418      AZ  aptincj992        p9p10  2021    1281.2  992   j
# 48460      AZ  aptincj992       p9p100  2021   16400.5  992   j
#
# [387 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year     value  age pop
# 46008      BA  aptincj992         p0p1  2021       0.0  992   j
# 46050      BA  aptincj992        p0p10  2021     349.5  992   j
# 46092      BA  aptincj992       p0p100  2021   13706.4  992   j
# 46134      BA  aptincj992        p0p50  2021    5039.2  992   j
# 46176      BA  aptincj992        p0p90  2021   10013.6  992   j
# ...       ...         ...          ...   ...       ...  ...  ..
# 56970      BA  aptincj992  p99.9p99.91  2021  204508.4  992   j
# 57012      BA  aptincj992      p99p100  2021  129354.7  992   j
# 57054      BA  aptincj992     p99p99.1  2021   72238.9  992   j
# 57096      BA  aptincj992        p9p10  2021    1258.1  992   j
# 57138      BA  aptincj992       p9p100  2021   15037.4  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year      value  age pop
# 1881       BD  aptincj992        p0p11  2021      964.3  992   j
# 1923       BD  aptincj992        p0p12  2021     1404.1  992   j
# 1965       BD  aptincj992        p0p13  2021     1932.9  992   j
# 2007       BD  aptincj992        p0p14  2021     2553.6  992   j
# 2049       BD  aptincj992        p0p15  2021     3269.5  992   j
# ...       ...         ...          ...   ...        ...  ...  ..
# 46977      BD  aptincj992  p99.9p99.91  2021  6454463.6  992   j
# 47019      BD  aptincj992      p99p100  2021  3622651.2  992   j
# 47061      BD  aptincj992     p99p99.1  2021  1884795.1  992   j
# 47103      BD  aptincj992        p9p10  2021    38821.3  992   j
# 47145      BD  aptincj992       p9p100  2021   341172.5  992   j
#
# [387 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year     value  age pop
# 57188      BE  aptincj992         p0p1  2021       0.0  992   j
# 57230      BE  aptincj992        p0p10  2021    1690.0  992   j
# 57272      BE  aptincj992       p0p100  2021   47695.1  992   j
# 57314      BE  aptincj992        p0p50  2021   19536.6  992   j
# 57356      BE  aptincj992        p0p90  2021   35632.1  992   j
# ...       ...         ...          ...   ...       ...  ...  ..
# 68150      BE  aptincj992  p99.9p99.91  2021  635139.1  992   j
# 68192      BE  aptincj992      p99p100  2021  408136.8  992   j
# 68234      BE  aptincj992     p99p99.1  2021  243174.3  992   j
# 68276      BE  aptincj992        p9p10  2021    6084.0  992   j
# 68318      BE  aptincj992       p9p100  2021   52293.4  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable percentile  year       value  age pop
# 31880      BF  aptincj992       p0p1  2021         0.0  992   j
# 31922      BF  aptincj992      p0p10  2021     16604.7  992   j
# 31964      BF  aptincj992     p0p100  2021   1000791.9  992   j
# 32006      BF  aptincj992      p0p50  2021    207279.8  992   j
# 32048      BF  aptincj992      p0p90  2021    502173.0  992   j
# ...       ...         ...        ...   ...         ...  ...  ..
# 42842      BF  aptincj992    p99p100  2021  15576186.1  992   j
# 42884      BF  aptincj992   p99p99.1  2021  10249171.7  992   j
# 42926      BF  aptincj992      p9p10  2021     59777.1  992   j
# 42968      BF  aptincj992     p9p100  2021   1098603.6  992   j
# 49021      BF  aptincj992    p37p100  2021   1497835.0  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year     value  age pop
# 54686      BG  aptincj992         p0p1  2021       0.0  992   j
# 54728      BG  aptincj992        p0p10  2021     641.9  992   j
# 54770      BG  aptincj992       p0p100  2021   22664.7  992   j
# 54812      BG  aptincj992        p0p50  2021    7587.1  992   j
# 54854      BG  aptincj992        p0p90  2021   14596.1  992   j
# ...       ...         ...          ...   ...       ...  ...  ..
# 65648      BG  aptincj992  p99.9p99.91  2021  612371.3  992   j
# 65690      BG  aptincj992      p99p100  2021  375457.5  992   j
# 65732      BG  aptincj992     p99p99.1  2021  153115.5  992   j
# 65774      BG  aptincj992        p9p10  2021    2310.9  992   j
# 65816      BG  aptincj992       p9p100  2021   24861.1  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year     value  age pop
# 31142      BH  aptincj992         p0p1  2021       0.0  992   j
# 31184      BH  aptincj992        p0p10  2021     198.3  992   j
# 31226      BH  aptincj992       p0p100  2021   12321.4  992   j
# 31268      BH  aptincj992        p0p50  2021    2521.8  992   j
# 31310      BH  aptincj992        p0p90  2021    6061.8  992   j
# ...       ...         ...          ...   ...       ...  ...  ..
# 42104      BH  aptincj992  p99.9p99.91  2021  480277.9  992   j
# 42146      BH  aptincj992      p99p100  2021  299870.6  992   j
# 42188      BH  aptincj992     p99p99.1  2021  136597.2  992   j
# 42230      BH  aptincj992        p9p10  2021     714.0  992   j
# 42272      BH  aptincj992       p9p100  2021   13526.0  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year       value  age pop
# 26094      BI  aptincj992         p0p1  2021         0.0  992   j
# 26136      BI  aptincj992        p0p10  2021     25330.8  992   j
# 26178      BI  aptincj992       p0p100  2021   1116842.3  992   j
# 26220      BI  aptincj992        p0p50  2021    313062.8  992   j
# 26262      BI  aptincj992        p0p90  2021    640497.5  992   j
# ...       ...         ...          ...   ...         ...  ...  ..
# 37056      BI  aptincj992  p99.9p99.91  2021  25589037.7  992   j
# 37098      BI  aptincj992      p99p100  2021  16465687.3  992   j
# 37140      BI  aptincj992     p99p99.1  2021   9844905.0  992   j
# 37182      BI  aptincj992        p9p10  2021     91192.9  992   j
# 37224      BI  aptincj992       p9p100  2021   1225517.8  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable percentile  year       value  age pop
# 30754      BJ  aptincj992      p0p10  2021     34747.8  992   j
# 30796      BJ  aptincj992     p0p100  2021   1501768.2  992   j
# 30838      BJ  aptincj992      p0p50  2021    427123.1  992   j
# 30880      BJ  aptincj992      p0p90  2021    885404.3  992   j
# 30922      BJ  aptincj992      p0p99  2021   1304108.2  992   j
# ...       ...         ...        ...   ...         ...  ...  ..
# 41716      BJ  aptincj992    p99p100  2021  21070100.3  992   j
# 41758      BJ  aptincj992   p99p99.1  2021  12771154.0  992   j
# 41800      BJ  aptincj992      p9p10  2021    125093.5  992   j
# 41842      BJ  aptincj992     p9p100  2021   1647850.9  992   j
# 46015      BJ  aptincj992       p0p1  2021         0.0  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year      value  age pop
# 1878       BN  aptincj992        p0p11  2021      222.1  992   j
# 1920       BN  aptincj992        p0p12  2021      323.4  992   j
# 1962       BN  aptincj992        p0p13  2021      445.2  992   j
# 2004       BN  aptincj992        p0p14  2021      588.1  992   j
# 2046       BN  aptincj992        p0p15  2021      753.0  992   j
# ...       ...         ...          ...   ...        ...  ...  ..
# 44642      BN  aptincj992  p99.9p99.91  2021  1163244.5  992   j
# 44684      BN  aptincj992      p99p100  2021   679811.7  992   j
# 44726      BN  aptincj992     p99p99.1  2021   322059.3  992   j
# 44768      BN  aptincj992        p9p10  2021     7016.6  992   j
# 44810      BN  aptincj992       p9p100  2021    59905.7  992   j
#
# [387 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year      value  age pop
# 38102      BO  aptincj992         p0p1  2021        0.0  992   j
# 38144      BO  aptincj992        p0p10  2021       37.0  992   j
# 38186      BO  aptincj992       p0p100  2021    34984.6  992   j
# 38228      BO  aptincj992        p0p50  2021     6520.7  992   j
# 38270      BO  aptincj992        p0p90  2021    18148.3  992   j
# ...       ...         ...          ...   ...        ...  ...  ..
# 49064      BO  aptincj992  p99.9p99.91  2021  1245287.6  992   j
# 49106      BO  aptincj992      p99p100  2021   686351.9  992   j
# 49148      BO  aptincj992     p99p99.1  2021   361049.8  992   j
# 49190      BO  aptincj992        p9p10  2021      293.6  992   j
# 49232      BO  aptincj992       p9p100  2021    38443.8  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#        country    variable percentile  year     value  age pop
# 18505       BR  aptincj992       p0p1  2021       0.0  992   j
# 18547       BR  aptincj992      p0p10  2021       0.0  992   j
# 18589       BR  aptincj992     p0p100  2021   52267.2  992   j
# 18631       BR  aptincj992      p0p50  2021    9581.7  992   j
# 18673       BR  aptincj992      p0p90  2021   24212.6  992   j
# ...        ...         ...        ...   ...       ...  ...  ..
# 114369      BR  aptincj992     p8p100  2021   56812.1  992   j
# 114411      BR  aptincj992      p9p10  2021       0.0  992   j
# 114453      BR  aptincj992     p9p100  2021   57436.4  992   j
# 152535      BR  aptincj992    p50p100  2021   94952.6  992   j
# 152577      BR  aptincj992     p98p99  2021  477132.3  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year      value  age pop
# 30611      BS  aptincj992         p0p1  2021        0.0  992   j
# 30653      BS  aptincj992        p0p10  2021       37.7  992   j
# 30695      BS  aptincj992       p0p100  2021    35661.1  992   j
# 30737      BS  aptincj992        p0p50  2021     6646.8  992   j
# 30779      BS  aptincj992        p0p90  2021    18499.2  992   j
# ...       ...         ...          ...   ...        ...  ...  ..
# 41573      BS  aptincj992  p99.9p99.91  2021  1269367.0  992   j
# 41615      BS  aptincj992      p99p100  2021   699624.3  992   j
# 41657      BS  aptincj992     p99p99.1  2021   368032.1  992   j
# 41699      BS  aptincj992        p9p10  2021      299.5  992   j
# 41741      BS  aptincj992       p9p100  2021    39187.2  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year       value  age pop
# 1543       BT  aptincj992        p0p11  2021       763.0  992   j
# 1585       BT  aptincj992        p0p12  2021      1111.1  992   j
# 1627       BT  aptincj992        p0p13  2021      1529.5  992   j
# 1669       BT  aptincj992        p0p14  2021      2020.7  992   j
# 1711       BT  aptincj992        p0p15  2021      2587.1  992   j
# ...       ...         ...          ...   ...         ...  ...  ..
# 41769      BT  aptincj992  p99.9p99.91  2021  10341119.1  992   j
# 41811      BT  aptincj992      p99p100  2021   5692855.0  992   j
# 41853      BT  aptincj992     p99p99.1  2021   2802283.7  992   j
# 41895      BT  aptincj992        p9p10  2021     21879.1  992   j
# 41937      BT  aptincj992       p9p100  2021    345489.9  992   j
#
# [387 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year      value  age pop
# 43551      BW  aptincj992         p0p1  2021        0.0  992   j
# 43593      BW  aptincj992        p0p10  2021     1243.0  992   j
# 43635      BW  aptincj992       p0p100  2021   102523.0  992   j
# 43677      BW  aptincj992        p0p50  2021    16649.8  992   j
# 43719      BW  aptincj992        p0p90  2021    46403.6  992   j
# ...       ...         ...          ...   ...        ...  ...  ..
# 54513      BW  aptincj992  p99.9p99.91  2021  3826389.1  992   j
# 54555      BW  aptincj992      p99p100  2021  2331145.9  992   j
# 54597      BW  aptincj992     p99p99.1  2021  1094566.8  992   j
# 54639      BW  aptincj992        p9p10  2021     4474.4  992   j
# 54681      BW  aptincj992       p9p100  2021   112575.2  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year     value  age pop
# 1878       BY  aptincj992        p0p11  2021      73.6  992   j
# 1920       BY  aptincj992        p0p12  2021     107.1  992   j
# 1962       BY  aptincj992        p0p13  2021     147.4  992   j
# 2004       BY  aptincj992        p0p14  2021     194.8  992   j
# 2046       BY  aptincj992        p0p15  2021     249.4  992   j
# ...       ...         ...          ...   ...       ...  ...  ..
# 42206      BY  aptincj992  p99.9p99.91  2021  296154.9  992   j
# 42248      BY  aptincj992      p99p100  2021  178917.6  992   j
# 42290      BY  aptincj992     p99p99.1  2021   93869.1  992   j
# 42332      BY  aptincj992        p9p10  2021    3582.0  992   j
# 42374      BY  aptincj992       p9p100  2021   22630.9  992   j
#
# [387 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year     value  age pop
# 31027      BZ  aptincj992         p0p1  2021       0.0  992   j
# 31069      BZ  aptincj992        p0p10  2021      16.8  992   j
# 31111      BZ  aptincj992       p0p100  2021   15862.2  992   j
# 31153      BZ  aptincj992        p0p50  2021    2956.5  992   j
# 31195      BZ  aptincj992        p0p90  2021    8228.5  992   j
# ...       ...         ...          ...   ...       ...  ...  ..
# 41989      BZ  aptincj992  p99.9p99.91  2021  564618.8  992   j
# 42031      BZ  aptincj992      p99p100  2021  311194.9  992   j
# 42073      BZ  aptincj992     p99p99.1  2021  163701.5  992   j
# 42115      BZ  aptincj992        p9p10  2021     133.2  992   j
# 42157      BZ  aptincj992       p9p100  2021   17430.6  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#        country    variable percentile  year      value  age pop
# 72835       CA  aptincj992       p0p1  2021        0.0  992   j
# 72907       CA  aptincj992      p0p10  2021     2139.6  992   j
# 72979       CA  aptincj992     p0p100  2021    72692.9  992   j
# 73051       CA  aptincj992      p0p11  2021      237.7  992   j
# 73123       CA  aptincj992      p0p12  2021      346.2  992   j
# ...        ...         ...        ...   ...        ...  ...  ..
# 100339      CA  aptincj992    p99p100  2021  1011376.3  992   j
# 100411      CA  aptincj992   p99p99.1  2021   422319.3  992   j
# 100483      CA  aptincj992      p9p10  2021     7702.5  992   j
# 100555      CA  aptincj992     p9p100  2021    79731.9  992   j
# 216480      CA  aptincj992       p1p2  2021        0.0  992   j
#
# [387 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year       value  age pop
# 25129      CD  aptincj992         p0p1  2021         0.0  992   j
# 25171      CD  aptincj992        p0p10  2021     50389.2  992   j
# 25213      CD  aptincj992       p0p100  2021   2602160.6  992   j
# 25255      CD  aptincj992        p0p50  2021    657860.3  992   j
# 25297      CD  aptincj992        p0p90  2021   1479279.1  992   j
# ...       ...         ...          ...   ...         ...  ...  ..
# 36091      CD  aptincj992  p99.9p99.91  2021  59203455.1  992   j
# 36133      CD  aptincj992      p99p100  2021  38077898.8  992   j
# 36175      CD  aptincj992     p99p99.1  2021  22739958.5  992   j
# 36217      CD  aptincj992        p9p10  2021    181406.0  992   j
# 36259      CD  aptincj992       p9p100  2021   2855973.3  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year       value  age pop
# 25345      CF  aptincj992         p0p1  2021         0.0  992   j
# 25387      CF  aptincj992        p0p10  2021      6560.7  992   j
# 25429      CF  aptincj992       p0p100  2021    624017.9  992   j
# 25471      CF  aptincj992        p0p50  2021     95247.8  992   j
# 25513      CF  aptincj992        p0p90  2021    243309.0  992   j
# ...       ...         ...          ...   ...         ...  ...  ..
# 36307      CF  aptincj992  p99.9p99.91  2021  31565275.8  992   j
# 36349      CF  aptincj992      p99p100  2021  19342579.3  992   j
# 36391      CF  aptincj992     p99p99.1  2021   7428737.3  992   j
# 36433      CF  aptincj992        p9p10  2021     23618.4  992   j
# 36475      CF  aptincj992       p9p100  2021    685272.5  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year       value  age pop
# 26297      CG  aptincj992         p0p1  2021         0.0  992   j
# 26339      CG  aptincj992        p0p10  2021     38130.4  992   j
# 26381      CG  aptincj992       p0p100  2021   2699592.8  992   j
# 26423      CG  aptincj992        p0p50  2021    535385.0  992   j
# 26465      CG  aptincj992        p0p90  2021   1321976.5  992   j
# ...       ...         ...          ...   ...         ...  ...  ..
# 37259      CG  aptincj992  p99.9p99.91  2021  88723318.1  992   j
# 37301      CG  aptincj992      p99p100  2021  55407350.8  992   j
# 37343      CG  aptincj992     p99p99.1  2021  30203610.9  992   j
# 37385      CG  aptincj992        p9p10  2021    137270.9  992   j
# 37427      CG  aptincj992       p9p100  2021   2963903.9  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year      value  age pop
# 57174      CH  aptincj992         p0p1  2021        0.0  992   j
# 57216      CH  aptincj992        p0p10  2021     3382.2  992   j
# 57258      CH  aptincj992       p0p100  2021    84106.1  992   j
# 57300      CH  aptincj992        p0p50  2021    39483.3  992   j
# 57342      CH  aptincj992        p0p90  2021    65010.3  992   j
# ...       ...         ...          ...   ...        ...  ...  ..
# 68136      CH  aptincj992  p99.9p99.91  2021  1305421.2  992   j
# 68178      CH  aptincj992      p99p100  2021   829384.8  992   j
# 68220      CH  aptincj992     p99p99.1  2021   368764.1  992   j
# 68262      CH  aptincj992        p9p10  2021    12175.9  992   j
# 68304      CH  aptincj992       p9p100  2021    92186.4  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year        value  age pop
# 2173       CI  aptincj992        p0p11  2021       5749.4  992   j
# 2215       CI  aptincj992        p0p12  2021       8372.1  992   j
# 2257       CI  aptincj992        p0p13  2021      11525.0  992   j
# 2299       CI  aptincj992        p0p14  2021      15225.9  992   j
# 2341       CI  aptincj992        p0p15  2021      19494.5  992   j
# ...       ...         ...          ...   ...          ...  ...  ..
# 49035      CI  aptincj992  p99.9p99.91  2021  101777341.5  992   j
# 49083      CI  aptincj992      p99p100  2021   60632284.1  992   j
# 49125      CI  aptincj992     p99p99.1  2021   31953413.6  992   j
# 49167      CI  aptincj992        p9p10  2021     197667.1  992   j
# 49209      CI  aptincj992       p9p100  2021    3164810.1  992   j
#
# [387 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#        country    variable percentile  year       value  age pop
# 17557       CL  aptincj992      p0p10  2021         0.0  992   j
# 17599       CL  aptincj992     p0p100  2021  15846782.1  992   j
# 17641       CL  aptincj992      p0p50  2021   2114485.4  992   j
# 17683       CL  aptincj992      p0p90  2021   7081439.3  992   j
# 17725       CL  aptincj992      p0p99  2021  12346658.3  992   j
# ...        ...         ...        ...   ...         ...  ...  ..
# 100957      CL  aptincj992    p42p100  2021  26336521.0  992   j
# 100999      CL  aptincj992     p44p45  2021   5907920.5  992   j
# 101041      CL  aptincj992     p73p74  2021  12397773.2  992   j
# 137767      CL  aptincj992      p9p10  2021         0.0  992   j
# 140911      CL  aptincj992     p94p95  2021  53349236.2  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year       value  age pop
# 31749      CM  aptincj992         p0p1  2021         0.0  992   j
# 31791      CM  aptincj992        p0p10  2021     28304.2  992   j
# 31833      CM  aptincj992       p0p100  2021   1859882.0  992   j
# 31875      CM  aptincj992        p0p50  2021    395574.1  992   j
# 31917      CM  aptincj992        p0p90  2021    990912.5  992   j
# ...       ...         ...          ...   ...         ...  ...  ..
# 42711      CM  aptincj992  p99.9p99.91  2021  45726822.4  992   j
# 42753      CM  aptincj992      p99p100  2021  29479371.0  992   j
# 42795      CM  aptincj992     p99p99.1  2021  17710832.8  992   j
# 42837      CM  aptincj992        p9p10  2021    101900.3  992   j
# 42879      CM  aptincj992       p9p100  2021   2041835.8  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#        country    variable  percentile  year      value  age pop
# 24060       CN  aptincj992       p0p10  2021     1543.4  992   j
# 24104       CN  aptincj992      p0p100  2021    92988.9  992   j
# 24148       CN  aptincj992       p0p50  2021    25547.6  992   j
# 24192       CN  aptincj992       p0p90  2021    58533.4  992   j
# 24236       CN  aptincj992       p0p99  2021    79163.8  992   j
# ...        ...         ...         ...   ...        ...  ...  ..
# 157150      CN  aptincj992      p98p99  2021   499407.0  992   j
# 157194      CN  aptincj992   p99.1p100  2021  1558413.4  992   j
# 157238      CN  aptincj992  p99.1p99.2  2021   615668.8  992   j
# 157282      CN  aptincj992   p99.2p100  2021  1676256.5  992   j
# 157353      CN  aptincj992     p29p100  2021   126057.0  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#        country    variable percentile  year       value  age pop
# 20818       CO  aptincj992       p0p1  2021         0.0  992   j
# 20860       CO  aptincj992      p0p10  2021         0.0  992   j
# 20902       CO  aptincj992     p0p100  2021  31495770.0  992   j
# 20944       CO  aptincj992      p0p50  2021   4300055.0  992   j
# 20986       CO  aptincj992      p0p90  2021  15530665.0  992   j
# ...        ...         ...        ...   ...         ...  ...  ..
# 107143      CO  aptincj992     p3p100  2021  32469866.0  992   j
# 107185      CO  aptincj992    p49p100  2021  57806625.3  992   j
# 107227      CO  aptincj992    p69p100  2021  83020682.8  992   j
# 107269      CO  aptincj992     p70p71  2021  25254487.7  992   j
# 144979      CO  aptincj992     p8p100  2021  34234532.6  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year        value  age pop
# 42285      CR  aptincj992         p0p1  2021          0.0  992   j
# 42327      CR  aptincj992        p0p10  2021          0.0  992   j
# 42369      CR  aptincj992       p0p100  2021    9799206.0  992   j
# 42411      CR  aptincj992        p0p50  2021    1203333.1  992   j
# 42453      CR  aptincj992        p0p90  2021    4898412.0  992   j
# ...       ...         ...          ...   ...          ...  ...  ..
# 53247      CR  aptincj992  p99.9p99.91  2021  299805146.0  992   j
# 53289      CR  aptincj992      p99p100  2021  173682717.9  992   j
# 53331      CR  aptincj992     p99p99.1  2021   99983381.1  992   j
# 53373      CR  aptincj992        p9p10  2021          0.0  992   j
# 53415      CR  aptincj992       p9p100  2021   10768358.2  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year      value  age pop
# 30013      CU  aptincj992         p0p1  2021        0.0  992   j
# 30055      CU  aptincj992        p0p10  2021      824.1  992   j
# 30097      CU  aptincj992       p0p100  2021   264906.2  992   j
# 30139      CU  aptincj992        p0p50  2021    68892.0  992   j
# 30181      CU  aptincj992        p0p90  2021   158785.9  992   j
# ...       ...         ...          ...   ...        ...  ...  ..
# 40975      CU  aptincj992  p99.9p99.91  2021  7233933.5  992   j
# 41017      CU  aptincj992      p99p100  2021  4008516.0  992   j
# 41059      CU  aptincj992     p99p99.1  2021  2211772.9  992   j
# 41101      CU  aptincj992        p9p10  2021     6536.9  992   j
# 41143      CU  aptincj992       p9p100  2021   291086.9  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year      value  age pop
# 27734      CV  aptincj992         p0p1  2021        0.0  992   j
# 27776      CV  aptincj992        p0p10  2021     8099.0  992   j
# 27818      CV  aptincj992       p0p100  2021   423625.4  992   j
# 27860      CV  aptincj992        p0p50  2021   104873.0  992   j
# 27902      CV  aptincj992        p0p90  2021   239665.4  992   j
# ...       ...         ...          ...   ...        ...  ...  ..
# 38696      CV  aptincj992  p99.9p99.91  2021  8867775.2  992   j
# 38738      CV  aptincj992      p99p100  2021  5893287.8  992   j
# 38780      CV  aptincj992     p99p99.1  2021  3788756.2  992   j
# 38822      CV  aptincj992        p9p10  2021    29156.2  992   j
# 38864      CV  aptincj992       p9p100  2021   464952.8  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year     value  age pop
# 51037      CY  aptincj992         p0p1  2021       0.0  992   j
# 51079      CY  aptincj992        p0p10  2021    1084.2  992   j
# 51121      CY  aptincj992       p0p100  2021   31205.2  992   j
# 51163      CY  aptincj992        p0p50  2021   12652.1  992   j
# 51205      CY  aptincj992        p0p90  2021   22953.6  992   j
# ...       ...         ...          ...   ...       ...  ...  ..
# 61999      CY  aptincj992  p99.9p99.91  2021  433872.1  992   j
# 62041      CY  aptincj992      p99p100  2021  277867.9  992   j
# 62083      CY  aptincj992     p99p99.1  2021  163536.1  992   j
# 62125      CY  aptincj992        p9p10  2021    3903.0  992   j
# 62167      CY  aptincj992       p9p100  2021   34215.2  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year      value  age pop
# 69687      CZ  aptincj992         p0p1  2021        0.0  992   j
# 69729      CZ  aptincj992        p0p10  2021    25260.1  992   j
# 69771      CZ  aptincj992       p0p100  2021   552484.4  992   j
# 69813      CZ  aptincj992        p0p50  2021   278603.8  992   j
# 69855      CZ  aptincj992        p0p90  2021   434139.0  992   j
# ...       ...         ...          ...   ...        ...  ...  ..
# 80649      CZ  aptincj992  p99.9p99.91  2021  9277054.9  992   j
# 80691      CZ  aptincj992      p99p100  2021  5863301.9  992   j
# 80733      CZ  aptincj992     p99p99.1  2021  2392007.5  992   j
# 80775      CZ  aptincj992        p9p10  2021    90938.0  992   j
# 80817      CZ  aptincj992       p9p100  2021   605349.2  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#        country    variable percentile  year     value  age pop
# 36939       DE  aptincj992       p0p1  2021       0.0  992   j
# 36981       DE  aptincj992      p0p10  2021    1345.9  992   j
# 37023       DE  aptincj992     p0p100  2021   45432.6  992   j
# 37065       DE  aptincj992      p0p50  2021   16929.9  992   j
# 37107       DE  aptincj992      p0p90  2021   31396.4  992   j
# ...        ...         ...        ...   ...       ...  ...  ..
# 185316      DE  aptincj992     p28p29  2021   20818.8  992   j
# 185358      DE  aptincj992     p48p49  2021   31609.9  992   j
# 185400      DE  aptincj992     p76p77  2021   53610.4  992   j
# 185442      DE  aptincj992    p79p100  2021  116693.3  992   j
# 185484      DE  aptincj992       p8p9  2021    3768.7  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year       value  age pop
# 30708      DJ  aptincj992         p0p1  2021         0.0  992   j
# 30750      DJ  aptincj992        p0p10  2021     16888.9  992   j
# 30792      DJ  aptincj992       p0p100  2021    842170.9  992   j
# 30834      DJ  aptincj992        p0p50  2021    220438.0  992   j
# 30876      DJ  aptincj992        p0p90  2021    472038.7  992   j
# ...       ...         ...          ...   ...         ...  ...  ..
# 41670      DJ  aptincj992  p99.9p99.91  2021  20624282.1  992   j
# 41712      DJ  aptincj992      p99p100  2021  13360606.1  992   j
# 41754      DJ  aptincj992     p99p99.1  2021   8123115.3  992   j
# 41796      DJ  aptincj992        p9p10  2021     60799.0  992   j
# 41838      DJ  aptincj992       p9p100  2021    924274.8  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year       value  age pop
# 73218      DK  aptincj992         p0p1  2021         0.0  992   j
# 73260      DK  aptincj992        p0p10  2021     18290.2  992   j
# 73302      DK  aptincj992       p0p100  2021    489688.6  992   j
# 73344      DK  aptincj992        p0p50  2021    207608.4  992   j
# 73386      DK  aptincj992        p0p90  2021    357226.8  992   j
# ...       ...         ...          ...   ...         ...  ...  ..
# 84180      DK  aptincj992  p99.9p99.91  2021  10055368.4  992   j
# 84222      DK  aptincj992      p99p100  2021   6564965.7  992   j
# 84264      DK  aptincj992     p99p99.1  2021   2389744.1  992   j
# 84306      DK  aptincj992        p9p10  2021     65844.6  992   j
# 84348      DK  aptincj992       p9p100  2021    536833.0  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year       value  age pop
# 1976       DO  aptincj992        p0p11  2021      1417.5  992   j
# 2018       DO  aptincj992        p0p12  2021      1834.3  992   j
# 2060       DO  aptincj992        p0p13  2021      2310.4  992   j
# 2102       DO  aptincj992        p0p14  2021      2855.7  992   j
# 2144       DO  aptincj992        p0p15  2021      3476.0  992   j
# ...       ...         ...          ...   ...         ...  ...  ..
# 54353      DO  aptincj992  p99.9p99.91  2021  53201623.9  992   j
# 54395      DO  aptincj992      p99p100  2021  21268234.9  992   j
# 54437      DO  aptincj992     p99p99.1  2021   6412657.3  992   j
# 54479      DO  aptincj992        p9p10  2021     24594.5  992   j
# 54521      DO  aptincj992       p9p100  2021    816133.2  992   j
#
# [387 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable percentile  year      value  age pop
# 11681      DZ  aptincj992       p0p1  2021        0.0  992   j
# 11723      DZ  aptincj992      p0p10  2021    27348.3  992   j
# 11765      DZ  aptincj992     p0p100  2021   848189.1  992   j
# 11807      DZ  aptincj992      p0p50  2021   322602.8  992   j
# 11849      DZ  aptincj992      p0p90  2021   583553.4  992   j
# ...       ...         ...        ...   ...        ...  ...  ..
# 22643      DZ  aptincj992     p9p100  2021   930152.6  992   j
# 87393      DZ  aptincj992     p28p29  2021   410100.3  992   j
# 87435      DZ  aptincj992    p30p100  2021  1123665.0  992   j
# 87477      DZ  aptincj992     p48p49  2021   581646.9  992   j
# 87519      DZ  aptincj992     p60p70  2021   769871.5  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year     value  age pop
# 42197      EC  aptincj992         p0p1  2021       0.0  992   j
# 42239      EC  aptincj992        p0p10  2021       0.0  992   j
# 42281      EC  aptincj992       p0p100  2021    8054.6  992   j
# 42323      EC  aptincj992        p0p50  2021    1654.7  992   j
# 42365      EC  aptincj992        p0p90  2021    4615.2  992   j
# ...       ...         ...          ...   ...       ...  ...  ..
# 53159      EC  aptincj992  p99.9p99.91  2021  225500.6  992   j
# 53201      EC  aptincj992      p99p100  2021  136417.4  992   j
# 53243      EC  aptincj992     p99p99.1  2021   75099.8  992   j
# 53285      EC  aptincj992        p9p10  2021       0.0  992   j
# 53327      EC  aptincj992       p9p100  2021    8851.2  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year     value  age pop
# 54118      EE  aptincj992         p0p1  2021       0.0  992   j
# 54160      EE  aptincj992        p0p10  2021     775.5  992   j
# 54202      EE  aptincj992       p0p100  2021   26655.4  992   j
# 54244      EE  aptincj992        p0p50  2021    8960.4  992   j
# 54286      EE  aptincj992        p0p90  2021   17727.4  992   j
# ...       ...         ...          ...   ...       ...  ...  ..
# 65080      EE  aptincj992  p99.9p99.91  2021  686654.2  992   j
# 65122      EE  aptincj992      p99p100  2021  433138.1  992   j
# 65164      EE  aptincj992     p99p99.1  2021  162362.2  992   j
# 65206      EE  aptincj992        p9p10  2021    2791.7  992   j
# 65248      EE  aptincj992       p9p100  2021   29237.1  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#        country    variable   percentile  year      value  age pop
# 14675       EG  aptincj992        p0p10  2021     2926.4  992   j
# 14717       EG  aptincj992       p0p100  2021   105168.9  992   j
# 14759       EG  aptincj992        p0p50  2021    32475.1  992   j
# 14801       EG  aptincj992        p0p90  2021    61228.4  992   j
# 14843       EG  aptincj992        p0p99  2021    87022.9  992   j
# ...        ...         ...          ...   ...        ...  ...  ..
# 90294       EG  aptincj992       p16p17  2021    26922.8  992   j
# 90336       EG  aptincj992       p68p69  2021    84748.3  992   j
# 90378       EG  aptincj992       p88p89  2021   183828.5  992   j
# 90420       EG  aptincj992  p99.9p99.91  2021  2987486.8  992   j
# 127110      EG  aptincj992         p0p1  2021        0.0  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year     value  age pop
# 24605      ER  aptincj992         p0p1  2021       0.0  992   j
# 24647      ER  aptincj992        p0p10  2021     503.8  992   j
# 24689      ER  aptincj992       p0p100  2021   19435.6  992   j
# 24731      ER  aptincj992        p0p50  2021    6155.3  992   j
# 24773      ER  aptincj992        p0p90  2021   11775.2  992   j
# ...       ...         ...          ...   ...       ...  ...  ..
# 35567      ER  aptincj992  p99.9p99.91  2021  418572.0  992   j
# 35609      ER  aptincj992      p99p100  2021  268606.1  992   j
# 35651      ER  aptincj992     p99p99.1  2021  159470.2  992   j
# 35693      ER  aptincj992        p9p10  2021    1813.7  992   j
# 35735      ER  aptincj992       p9p100  2021   21322.4  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#        country    variable percentile  year    value  age pop
# 42349       ES  aptincj992       p0p1  2021      0.0  992   j
# ...
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#        country    variable percentile  year      value  age pop
# 13244       TR  aptincj992      p0p10  2021     4649.1  992   j
# 13286       TR  aptincj992     p0p100  2021   199067.3  992   j
# 13328       TR  aptincj992      p0p50  2021    56473.3  992   j
# 13370       TR  aptincj992      p0p90  2021   106882.1  992   j
# 13412       TR  aptincj992      p0p99  2021   163308.6  992   j
# ...        ...         ...        ...   ...        ...  ...  ..
# 86205       TR  aptincj992     p60p70  2021   135568.1  992   j
# 86247       TR  aptincj992     p74p75  2021   165065.8  992   j
# 86289       TR  aptincj992     p88p89  2021   339025.8  992   j
# 123252      TR  aptincj992     p98p99  2021  1342655.8  992   j
# 123294      TR  aptincj992   p99p99.1  2021  2300338.3  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year      value  age pop
# 35879      TT  aptincj992         p0p1  2021        0.0  992   j
# 35921      TT  aptincj992        p0p10  2021      149.9  992   j
# 35963      TT  aptincj992       p0p100  2021   141646.5  992   j
# 36005      TT  aptincj992        p0p50  2021    26401.4  992   j
# 36047      TT  aptincj992        p0p90  2021    73479.1  992   j
# ...       ...         ...          ...   ...        ...  ...  ..
# 46841      TT  aptincj992  p99.9p99.91  2021  5041950.5  992   j
# 46883      TT  aptincj992      p99p100  2021  2778918.3  992   j
# 46925      TT  aptincj992     p99p99.1  2021  1461827.1  992   j
# 46967      TT  aptincj992        p9p10  2021     1188.7  992   j
# 47009      TT  aptincj992       p9p100  2021   155652.1  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year       value  age pop
# 29633      TW  aptincj992         p0p1  2021         0.0  992   j
# 29675      TW  aptincj992        p0p10  2021     13454.2  992   j
# 29717      TW  aptincj992       p0p100  2021    958689.7  992   j
# 29759      TW  aptincj992        p0p50  2021    225980.4  992   j
# 29801      TW  aptincj992        p0p90  2021    552586.7  992   j
# ...       ...         ...          ...   ...         ...  ...  ..
# 40595      TW  aptincj992  p99.9p99.91  2021  26154128.8  992   j
# 40637      TW  aptincj992      p99p100  2021  18534763.9  992   j
# 40679      TW  aptincj992     p99p99.1  2021   7305950.5  992   j
# 40721      TW  aptincj992        p9p10  2021     48433.9  992   j
# 40763      TW  aptincj992       p9p100  2021   1052558.9  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable  percentile  year       value  age pop
# 30961      TZ  aptincj992        p0p1  2021         0.0  992   j
# 31003      TZ  aptincj992       p0p10  2021    102374.3  992   j
# 31045      TZ  aptincj992      p0p100  2021   4799919.0  992   j
# 31087      TZ  aptincj992       p0p50  2021   1242905.8  992   j
# 31129      TZ  aptincj992       p0p90  2021   2593609.9  992   j
# ...       ...         ...         ...   ...         ...  ...  ..
# 41923      TZ  aptincj992     p99p100  2021  87134609.8  992   j
# 41965      TZ  aptincj992    p99p99.1  2021  46544982.3  992   j
# 42007      TZ  aptincj992       p9p10  2021    368550.8  992   j
# 42049      TZ  aptincj992      p9p100  2021   5267436.4  992   j
# 54909      TZ  aptincj992  p99.6p99.7  2021  75247031.2  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year      value  age pop
# 1860       UA  aptincj992        p0p11  2021      559.3  992   j
# 1902       UA  aptincj992        p0p12  2021      814.4  992   j
# 1944       UA  aptincj992        p0p13  2021     1121.2  992   j
# 1986       UA  aptincj992        p0p14  2021     1481.2  992   j
# 2028       UA  aptincj992        p0p15  2021     1896.4  992   j
# ...       ...         ...          ...   ...        ...  ...  ..
# 48943      UA  aptincj992  p99.9p99.91  2021  4177182.2  992   j
# 48985      UA  aptincj992      p99p100  2021  2409487.2  992   j
# 49027      UA  aptincj992     p99p99.1  2021  1074660.2  992   j
# 49069      UA  aptincj992        p9p10  2021    18852.0  992   j
# 49111      UA  aptincj992       p9p100  2021   194378.2  992   j
#
# [387 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year        value  age pop
# 30574      UG  aptincj992         p0p1  2021          0.0  992   j
# 30616      UG  aptincj992        p0p10  2021     140079.8  992   j
# 30658      UG  aptincj992       p0p100  2021    7202641.5  992   j
# 30700      UG  aptincj992        p0p50  2021    1764669.5  992   j
# 30742      UG  aptincj992        p0p90  2021    3775395.7  992   j
# ...       ...         ...          ...   ...          ...  ...  ..
# 41536      UG  aptincj992  p99.9p99.91  2021  225721737.1  992   j
# 41578      UG  aptincj992      p99p100  2021  138918048.5  992   j
# 41620      UG  aptincj992     p99p99.1  2021   70776622.3  992   j
# 41662      UG  aptincj992        p9p10  2021     504268.6  992   j
# 41704      UG  aptincj992       p9p100  2021    7905138.7  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#        country    variable percentile  year     value  age pop
# 113810      US  aptincj992      p0p10  2021    3381.6  992   j
# 113919      US  aptincj992     p0p100  2021   84626.0  992   j
# 114028      US  aptincj992      p0p50  2021   23395.3  992   j
# 114137      US  aptincj992      p0p90  2021   51148.1  992   j
# 114246      US  aptincj992      p0p99  2021   69210.3  992   j
# ...        ...         ...        ...   ...       ...  ...  ..
# 439774      US  aptincj992       p6p7  2021    5561.6  992   j
# 439883      US  aptincj992      p9p10  2021    9598.4  992   j
# 439992      US  aptincj992     p9p100  2021   92729.5  992   j
# 503017      US  aptincj992       p0p1  2021   -4120.0  992   j
# 503126      US  aptincj992    p75p100  2021  224766.9  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable percentile  year       value  age pop
# 35688      UY  aptincj992      p0p10  2021      9241.5  992   j
# 35730      UY  aptincj992     p0p100  2021    990902.3  992   j
# 35772      UY  aptincj992      p0p50  2021    306622.8  992   j
# 35814      UY  aptincj992      p0p90  2021    633046.2  992   j
# 35856      UY  aptincj992      p0p99  2021    866871.2  992   j
# ...       ...         ...        ...   ...         ...  ...  ..
# 46650      UY  aptincj992    p99p100  2021  13269983.5  992   j
# 46692      UY  aptincj992   p99p99.1  2021   7466562.8  992   j
# 46734      UY  aptincj992      p9p10  2021     73314.1  992   j
# 46776      UY  aptincj992     p9p100  2021   1088693.7  992   j
# 61888      UY  aptincj992       p0p1  2021         0.0  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable percentile  year        value  age pop
# 1660       UZ  aptincj992      p0p11  2021      68370.6  992   j
# 1702       UZ  aptincj992      p0p12  2021      99559.5  992   j
# 1744       UZ  aptincj992      p0p13  2021     137051.7  992   j
# 1786       UZ  aptincj992      p0p14  2021     181064.7  992   j
# 1828       UZ  aptincj992      p0p15  2021     231824.0  992   j
# ...       ...         ...        ...   ...          ...  ...  ..
# 40721      UZ  aptincj992    p99p100  2021  536267073.7  992   j
# 40763      UZ  aptincj992   p99p99.1  2021  304784340.7  992   j
# 40805      UZ  aptincj992      p9p10  2021    1838522.7  992   j
# 40847      UZ  aptincj992     p9p100  2021   33751886.3  992   j
# 52941      UZ  aptincj992     p93p94  2021   77726240.2  992   j
#
# [387 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable percentile  year    value  age pop
# 44305      VE  aptincj992       p0p1  2021      0.0  992   j
# 44347      VE  aptincj992      p0p10  2021     50.5  992   j
# 44389      VE  aptincj992     p0p100  2021  43045.7  992   j
# 44431      VE  aptincj992      p0p50  2021   7227.1  992   j
# 44473      VE  aptincj992      p0p90  2021  21401.7  992   j
# ...       ...         ...        ...   ...      ...  ...  ..
# 55267      VE  aptincj992      p9p10  2021    388.7  992   j
# 55309      VE  aptincj992     p9p100  2021  47301.7  992   j
# 73466      VE  aptincj992       p1p2  2021      0.0  992   j
# 73508      VE  aptincj992       p3p4  2021      0.0  992   j
# 73550      VE  aptincj992       p4p5  2021      0.0  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable percentile  year        value  age pop
# 1903       VN  aptincj992      p0p11  2021     206829.7  992   j
# 1945       VN  aptincj992      p0p12  2021     301175.3  992   j
# 1987       VN  aptincj992      p0p13  2021     414590.1  992   j
# 2029       VN  aptincj992      p0p14  2021     547731.4  992   j
# 2071       VN  aptincj992      p0p15  2021     701281.9  992   j
# ...       ...         ...        ...   ...          ...  ...  ..
# 44774      VN  aptincj992      p9p10  2021    8632813.4  992   j
# 44816      VN  aptincj992     p9p100  2021  115600088.8  992   j
# 56585      VN  aptincj992     p72p73  2021  103227676.3  992   j
# 56627      VN  aptincj992     p75p76  2021  113798288.8  992   j
# 56669      VN  aptincj992     p80p81  2021  135402927.8  992   j
#
# [387 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year       value  age pop
# 25594      YE  aptincj992         p0p1  2021         0.0  992   j
# 25636      YE  aptincj992        p0p10  2021     13606.4  992   j
# 25678      YE  aptincj992       p0p100  2021    974044.1  992   j
# 25720      YE  aptincj992        p0p50  2021    181921.8  992   j
# 25762      YE  aptincj992        p0p90  2021    452858.7  992   j
# ...       ...         ...          ...   ...         ...  ...  ..
# 36556      YE  aptincj992  p99.9p99.91  2021  38773662.4  992   j
# 36598      YE  aptincj992      p99p100  2021  23572022.9  992   j
# 36640      YE  aptincj992     p99p99.1  2021  11871114.4  992   j
# 36682      YE  aptincj992        p9p10  2021     48983.2  992   j
# 36724      YE  aptincj992       p9p100  2021   1069421.2  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#        country    variable percentile  year     value  age pop
# 125731      ZA  aptincj992      p0p50  2021   16988.0  992   j
# 125773      ZA  aptincj992      p0p90  2021   56247.4  992   j
# 125815      ZA  aptincj992      p0p99  2021  119269.5  992   j
# 125857      ZA  aptincj992    p10p100  2021  162451.1  992   j
# 125899      ZA  aptincj992     p10p11  2021    5462.6  992   j
# ...        ...         ...        ...   ...       ...  ...  ..
# 481861      ZA  aptincj992     p30p31  2021   20862.1  992   j
# 521595      ZA  aptincj992       p0p1  2021       0.0  992   j
# 521637      ZA  aptincj992       p1p2  2021       0.0  992   j
# 521679      ZA  aptincj992       p2p3  2021       0.0  992   j
# 521721      ZA  aptincj992       p4p5  2021       0.0  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year      value  age pop
# 30533      ZM  aptincj992         p0p1  2021        0.0  992   j
# 30575      ZM  aptincj992        p0p10  2021      479.7  992   j
# 30617      ZM  aptincj992       p0p100  2021    50653.0  992   j
# 30659      ZM  aptincj992        p0p50  2021     7039.6  992   j
# 30701      ZM  aptincj992        p0p90  2021    21535.9  992   j
# ...       ...         ...          ...   ...        ...  ...  ..
# 41495      ZM  aptincj992  p99.9p99.91  2021  1911244.4  992   j
# 41537      ZM  aptincj992      p99p100  2021  1173592.6  992   j
# 41579      ZM  aptincj992     p99p99.1  2021   589753.0  992   j
# 41621      ZM  aptincj992        p9p10  2021     1727.0  992   j
# 41663      ZM  aptincj992       p9p100  2021    55628.9  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
#       country    variable   percentile  year       value  age pop
# 30923      ZW  aptincj992         p0p1  2021         0.0  992   j
# 30965      ZW  aptincj992        p0p10  2021      5877.5  992   j
# 31007      ZW  aptincj992       p0p100  2021    414444.8  992   j
# 31049      ZW  aptincj992        p0p50  2021     76533.0  992   j
# 31091      ZW  aptincj992        p0p90  2021    189016.5  992   j
# ...       ...         ...          ...   ...         ...  ...  ..
# 41885      ZW  aptincj992  p99.9p99.91  2021  13831612.9  992   j
# 41927      ZW  aptincj992      p99p100  2021   8735232.2  992   j
# 41969      ZW  aptincj992     p99p99.1  2021   4951924.7  992   j
# 42011      ZW  aptincj992       p9p100  2021    455020.5  992   j
# 56056      ZW  aptincj992        p9p10  2021     21160.5  992   j
#
# [266 rows x 7 columns]
# Columns in DataFrame: Index(['country', 'variable', 'percentile', 'year', 'value', 'age', 'pop'], dtype='object')
# Empty DataFrame
# Columns: [country, variable, percentile, year, value, age, pop]
# Index: []
# Dataframes differ in format/dimensions.

# %%
test = subset_dfs['AT']
print(test)
# Out:
#       country    variable percentile  year      value  age pop
# 54309      AT  aptincj992       p0p1  2021        0.0  992   j
# 54351      AT  aptincj992      p0p10  2021     1858.1  992   j
# 54393      AT  aptincj992     p0p100  2021    47801.0  992   j
# 54435      AT  aptincj992      p0p50  2021    21188.9  992   j
# 54477      AT  aptincj992      p0p90  2021    34816.4  992   j
# ...       ...         ...        ...   ...        ...  ...  ..
# 65271      AT  aptincj992     p9p100  2021    52397.9  992   j
# 89244      AT  aptincj992    p71p100  2021    97443.7  992   j
# 89286      AT  aptincj992     p86p87  2021    71166.5  992   j
# 89328      AT  aptincj992  p99.8p100  2021  1213866.9  992   j
# 89370      AT  aptincj992      p9p10  2021     6689.0  992   j
#
# [266 rows x 7 columns]

# %%
# clear empty dataframes from dictionary    
subset_dfs = {k: v for k, v in subset_dfs.items() if not v.empty}
# adjust dimensions of dictionary

# %%
# subset percentiles in each dataframe in the dictionary
# based on column percentile and values 

percentile_values = ['p0p10', 'p10p20', 'p20p30', 'p30p40', 'p40p50', 'p50p60', 'p60p70', 'p70p80', 'p80p90', 
                     'p90p91', 'p91p92', 'p92p93', 'p93p94', 'p94p95', 'p95p96', 'p96p97', 'p97p98', 'p98p99', 
                     'p99p99.1', 'p99.1p99.2', 'p99.2p99.3', 'p99.3p99.4', 'p99.4p99.5', 'p99.5p99.6', 'p99.6p99.7','p99.7p99.8', 'p99.8p99.9', 'p99.9p100']
# Initialize a dictionary to store the subset dataframes
subset_dfs2 = {}

# Iterate all countries in the dictionary and extract the percentiles
for code, df in subset_dfs.items():
    # Subset the dataframe based on 'variable' which is
    #  pre-tax national income distributional accounts
    #  and 'year'
    subset_df = df[df['percentile'].isin(percentile_values)]
    # Store the subset dataframe in the dictionary
    subset_dfs2[code] = subset_df

# Check if all dataframes have the same format/dimensions
if subset_dfs2:  # Check if there's at least one dataframe in the dictionary
    first_df_shape = next(iter(subset_dfs2.values())).shape
    consistent_format = all(df.shape == first_df_shape for df in subset_dfs2.values())

    if consistent_format:
        print("All dataframes have the same format and dimensions.")
    else:
        print("Dataframes differ in format/dimensions.")


# store one dataframe for visual inspection as test2
test2 = subset_dfs2['AT']
# Out:
# All dataframes have the same format and dimensions.

# %%
# make a list of all countries in the dataframe subset_dfs2
countries_list = list(subset_dfs2.keys())

# ALSO store the name of the each country in the subseT_dfs2 dictionary
# in another list and then combine the countries_list and the country_names_list
# into a dictionary
country_names_list = []
for code in countries_list:
    country_names_list.append(countries.loc[countries['alpha2'] == code, 'titlename'].iloc[0])

# combine the two lists into a dictionary
country_dict = dict(zip(countries_list, country_names_list))

# %%
# Get the list of countries for which the variable ntaxad992t exists in the original data
countries_with_variable = [code for code, df in subset_dfs.items() if 'ntaxadt992' in df['variable'].values]

# Compare the countries with variable ntaxad992t to the countries in country_dict
countries_with_variable_in_dict = [code for code in countries_with_variable if code in country_dict]

# Print the list of countries
print(countries_with_variable_in_dict)
# Out:
# []

# %%
# check for what countries ntaxadt999 that is the adult population data exists

# Define your desired directory
desired_directory = r'C:\Users\y-osw\Dropbox\Arbeit\postdoc_lausanne\convergence\data\wid_all_data'

# Base path for debugging
file_path_to_data = os.path.join('.', 'data\wid_all_data')
print("Base path:", file_path_to_data)
print("Current working directory:", os.getcwd())

# Initialize a list to store countries where 'ntaxadt992' is present
countries_with_variable = []

# Iterate over the unique codes in the 'alpha2' column
for code in countries['alpha2'].unique():
    # Construct the file name for the respective dataframe
    file_name = f'WID_data_{code}.csv'  # Assuming the files are .csv
    full_file_path = os.path.join(desired_directory, file_name)

    # Check if the file exists
    if os.path.exists(full_file_path):
        # Load the dataframe
        df = pd.read_csv(full_file_path, sep = ";")

        # Check if 'ntaxadt992' exists in this dataframe
        if 'ntaxadt992' in df['variable'].unique():
            # Get the country name (assuming a 'country_name' column exists)
            # country name comes from the countries dataframe and its column short name
            country_name = countries.loc[countries['alpha2'] == code, 'shortname'].iloc[0]  

            # Add the country code and name to the list
            countries_with_variable.append((code, country_name))

# Print the list of countries with 'ntaxadt992'
print("Countries with 'ntaxadt992':", countries_with_variable)
# Out:
# Base path: .\data\wid_all_data
# Current working directory: c:\Users\y-osw\Dropbox\Arbeit\postdoc_lausanne\convergence
# Countries with 'ntaxadt992': [('AR', 'Argentina'), ('AU', 'Australia'), ('BE', 'Belgium'), ('CA', 'Canada'), ('CO', 'Colombia'), ('DK', 'Denmark'), ('ES', 'Spain'), ('FI', 'Finland'), ('GB', 'United Kingdom'), ('HU', 'Hungary'), ('IN', 'India'), ('IT', 'Italy'), ('JP', 'Japan'), ('KR', 'Korea'), ('MY', 'Malaysia'), ('NO', 'Norway'), ('NZ', 'New Zealand'), ('SE', 'Sweden'), ('SG', 'Singapore'), ('UY', 'Uruguay'), ('ZA', 'South Africa')]
